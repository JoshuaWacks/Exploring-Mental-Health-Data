# %% [markdown]
# Student Data

# %%
import pandas as pd
from utility import group_and_compare

# %%
student_data = pd.read_csv("../data_split_0/student_train_data.csv")

# %%
student_data.head()
# Out:
#    id       Name  Gender   Age           City  Academic Pressure  \
# 0   2     Yuvraj    Male  33.0  Visakhapatnam                5.0
# 1   8  Aishwarya  Female  24.0      Bangalore                2.0
# 2  26     Aditya    Male  31.0       Srinagar                3.0
# 3  30     Prisha  Female  28.0       Varanasi                3.0
# 4  32     Chhavi  Female  25.0         Jaipur                4.0
#
#    Study Satisfaction     Sleep Duration Dietary Habits   Degree  \
# 0                 2.0          5-6 hours        Healthy  B.Pharm
# 1                 5.0          5-6 hours       Moderate      BSc
# 2                 5.0  Less than 5 hours        Healthy       BA
# 3                 2.0          7-8 hours       Moderate      BCA
# 4                 3.0          5-6 hours       Moderate   M.Tech
#
#   Have you ever had suicidal thoughts ?  Work/Study Hours  Financial Stress  \
# 0                                   Yes               3.0               1.0
# ...

# %%
student_data[student_data['City'] == "3.0"]
# Out:
#          id   Name  Gender   Age City  Academic Pressure  Study Satisfaction  \
# 7021  35309  Sanya  Female  21.0  3.0                3.0                 4.0
#
#      Sleep Duration Dietary Habits Degree  \
# 7021      7-8 hours      Unhealthy    BCA
#
#      Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 7021                                   Yes              11.0
#
#       Financial Stress Family History of Mental Illness  Depression
# 7021               5.0                               No           1

# %%
data = student_data
inde = 'City'
depe = 'Depression'
min_percentage = 0.01

# %%
independ_vars = list(student_data.columns)

# %%
independ_vars.remove('id')
independ_vars.remove('Name')
independ_vars.remove('Depression')

# %%
independ_vars
# Out:
# ['Gender',
#  'Age',
#  'City',
#  'Academic Pressure',
#  'Study Satisfaction',
#  'Sleep Duration',
#  'Dietary Habits',
#  'Degree',
#  'Have you ever had suicidal thoughts ?',
#  'Work/Study Hours',
#  'Financial Stress',
#  'Family History of Mental Illness']

# %%
for inde in independ_vars:
    
    group_and_compare(data = student_data,
                      inde=inde,
                      depe=depe,
                      min_percentage=min_percentage)

# %%
prof_data = pd.read_csv("../data_split_0/prof_train_data.csv")

# %%
independ_vars = list(prof_data.columns)

# %%
independ_vars.remove('id')
independ_vars.remove('Name')
independ_vars.remove('Depression')

# %%
for inde in independ_vars:
    
    group_and_compare(data = prof_data,
                      inde=inde,
                      depe=depe,
                      min_percentage=min_percentage)
