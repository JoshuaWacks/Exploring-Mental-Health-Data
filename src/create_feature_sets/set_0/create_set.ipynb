# %% [markdown]
# TODO look if invalid data correlates and can be adjusted for in that way.
#
# Was it a capture thing that they mixed up 2 columns, look at the rows I am removing

# %% [markdown]
# TODO add gitignore

# %% [markdown]
# Using preprocess set 0 and data_split_0

# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer


from student_preprocess import StudentPreprocessSet0
from prof_preprocess import ProfPreprocessSet0

# %%
org_student_data =pd.read_csv('../../data/data_split_0/student_train_data.csv')

# %%
cols_to_drop=['id','Name']

imputer = SimpleImputer(missing_values=np.nan,strategy='median')


student_preprocessor = StudentPreprocessSet0(df=org_student_data,
                                             cols_to_drop=cols_to_drop,
                                             imputer=imputer,
                                             cat_encoding_type="frequency")

# %%
student_preprocessor.preprocess()

# %%
student_clean_df=student_preprocessor.df

# %%
student_clean_df[student_clean_df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [id, Name, Gender, Age, City, Academic Pressure, Study Satisfaction, Sleep Duration, Dietary Habits, Degree, Have you ever had suicidal thoughts ?, Work/Study Hours, Financial Stress, Family History of Mental Illness, Depression]
# Index: []

# %%
student_clean_df
# Out:
#            id      Name    Gender   Age      City  Academic Pressure  \
# 0           2  0.004447  0.557205  33.0  0.034754                5.0
# 1           8  0.008751  0.442795  24.0  0.027509                2.0
# 2          26  0.007030  0.557205  31.0  0.049100                3.0
# 3          30  0.009397  0.442795  28.0  0.024568                3.0
# 4          32  0.010473  0.442795  25.0  0.037121                4.0
# ...       ...       ...       ...   ...       ...                ...
# 27896  140685  0.015279  0.442795  27.0  0.038663                5.0
# 27897  140686  0.014920  0.557205  27.0  0.039811                2.0
# 27898  140689  0.015817  0.557205  31.0  0.016534                3.0
# 27899  140690  0.011620  0.442795  18.0  0.039811                5.0
# 27900  140699  0.004447  0.557205  27.0  0.036116                4.0
#
#        Study Satisfaction  Sleep Duration  Dietary Habits    Degree  \
# 0                     2.0        0.221828        0.274335  0.029015
# ...

# %%
student_clean_df.to_csv('../../data/clean_data_0/student_train_data.csv',index=False)

# %%
org_prof_data =pd.read_csv('../../data/data_split_0/prof_train_data.csv')

# %%
cols_to_drop=['id','Name']

imputer = SimpleImputer(missing_values=np.nan,strategy='median')

prof_preprocessor = ProfPreprocessSet0(df=org_prof_data,
                                             cols_to_drop=cols_to_drop,
                                             imputer=imputer,
                                             cat_encoding_type="frequency")

# %%
prof_preprocessor.preprocess()

# %%
prof_clean_df=prof_preprocessor.df

# %%
prof_clean_df[prof_clean_df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [id, Name, Gender, Age, City, Profession, Work Pressure, Job Satisfaction, Sleep Duration, Dietary Habits, Degree, Have you ever had suicidal thoughts ?, Work/Study Hours, Financial Stress, Family History of Mental Illness, Depression]
# Index: []

# %%
prof_clean_df
# Out:
#             id      Name    Gender   Age      City  Profession  Work Pressure  \
# 0            0  0.014339  0.451068  49.0  0.036491    0.025362            5.0
# 1            1  0.007174  0.548932  26.0  0.034753    0.298409            4.0
# 2            3  0.005374  0.548932  22.0  0.037830    0.298409            5.0
# 3            4  0.003467  0.451068  30.0  0.033600    0.028031            1.0
# 4            5  0.012291  0.451068  59.0  0.041333    0.011785            2.0
# ...        ...       ...       ...   ...       ...         ...            ...
# 112794  140694  0.011058  0.451068  45.0  0.041333    0.298409            2.0
# 112795  140695  0.010278  0.451068  18.0  0.041333    0.298409            5.0
# 112796  140696  0.001543  0.451068  41.0  0.027960    0.069266            5.0
# 112797  140697  0.004647  0.451068  24.0  0.040987    0.017523            3.0
# 112798  140698  0.008664  0.451068  49.0  0.032811    0.015492            5.0
#
# ...

# %%
prof_clean_df.to_csv('../../data/clean_data_0/prof_train_data.csv',index=False)
