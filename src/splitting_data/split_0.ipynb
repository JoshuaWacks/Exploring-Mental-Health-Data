# %% [markdown]
# Splitting by student and profession

# %% [markdown]
# This is split 0

# %%
import pandas as pd

# %%
org_data = pd.read_csv("../original_data/train.csv")

# %%
org_data['Working Professional or Student'].value_counts()
# Out:
# Working Professional or Student
# Working Professional    112799
# Student                  27901
# Name: count, dtype: int64

# %%
prof_data = org_data.loc[org_data['Working Professional or Student'] == 'Working Professional']
student_data = org_data.loc[org_data['Working Professional or Student'] == 'Student']

# %% [markdown]
# Need to drop columns that no longer apply

# %%
prof_data.head()
# Out:
#    id      Name  Gender   Age       City Working Professional or Student  \
# 0   0  Aaradhya  Female  49.0   Ludhiana            Working Professional
# 1   1     Vivan    Male  26.0   Varanasi            Working Professional
# 3   3    Yuvraj    Male  22.0     Mumbai            Working Professional
# 4   4      Rhea  Female  30.0     Kanpur            Working Professional
# 5   5      Vani  Female  59.0  Ahmedabad            Working Professional
#
#             Profession  Academic Pressure  Work Pressure  CGPA  \
# 0                 Chef                NaN            5.0   NaN
# 1              Teacher                NaN            4.0   NaN
# 3              Teacher                NaN            5.0   NaN
# 4     Business Analyst                NaN            1.0   NaN
# 5  Finanancial Analyst                NaN            2.0   NaN
#
#    Study Satisfaction  Job Satisfaction     Sleep Duration Dietary Habits  \
# ...

# %% [markdown]
# Even though there are still some values left here, these are possibly errounous captures or outliers

# %%
prof_data[~prof_data['Study Satisfaction'].isna()].index
# Out:
# Index([18752, 41915, 55827, 60348, 99062, 101189], dtype='int64')

# %%
prof_data['Academic Pressure'].value_counts()
# Out:
# Academic Pressure
# 4.0    3
# 2.0    1
# 3.0    1
# Name: count, dtype: int64

# %%
prof_data_irrelevant_columns = ['Working Professional or Student','Academic Pressure','CGPA','Study Satisfaction']
prof_data = prof_data.drop(columns=prof_data_irrelevant_columns,axis=1)

# %%
prof_data.head()
# Out:
#    id      Name  Gender   Age       City           Profession  Work Pressure  \
# 0   0  Aaradhya  Female  49.0   Ludhiana                 Chef            5.0
# 1   1     Vivan    Male  26.0   Varanasi              Teacher            4.0
# 3   3    Yuvraj    Male  22.0     Mumbai              Teacher            5.0
# 4   4      Rhea  Female  30.0     Kanpur     Business Analyst            1.0
# 5   5      Vani  Female  59.0  Ahmedabad  Finanancial Analyst            2.0
#
#    Job Satisfaction     Sleep Duration Dietary Habits Degree  \
# 0               2.0  More than 8 hours        Healthy    BHM
# 1               3.0  Less than 5 hours      Unhealthy    LLB
# 3               1.0  Less than 5 hours       Moderate    BBA
# 4               1.0          5-6 hours      Unhealthy    BBA
# 5               5.0          5-6 hours        Healthy    MCA
#
#   Have you ever had suicidal thoughts ?  Work/Study Hours  Financial Stress  \
# ...

# %% [markdown]
# Look into the possibility of analysing these guys as students:
#
#
# prof_data[~prof_data['Study Satisfaction'].isna()]
#
#
# Index([18752, 41915, 55827, 60348, 99062, 101189], dtype='int64')

# %%
prof_data.to_csv('../data_split_0/prof_train_data.csv',index=False)

# %%
student_data.head()
# Out:
#     id       Name  Gender   Age           City  \
# 2    2     Yuvraj    Male  33.0  Visakhapatnam
# 8    8  Aishwarya  Female  24.0      Bangalore
# 26  26     Aditya    Male  31.0       Srinagar
# 30  30     Prisha  Female  28.0       Varanasi
# 32  32     Chhavi  Female  25.0         Jaipur
#
#    Working Professional or Student Profession  Academic Pressure  \
# 2                          Student        NaN                5.0
# 8                          Student        NaN                2.0
# 26                         Student        NaN                3.0
# 30                         Student        NaN                3.0
# 32                         Student        NaN                4.0
#
#     Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 2             NaN  8.97                 2.0               NaN
# 8             NaN  5.90                 5.0               NaN
# 26            NaN  7.03                 5.0               NaN
# ...

# %%
student_data[student_data['Profession'].isna()]
# Out:
#             id       Name  Gender   Age           City  \
# 2            2     Yuvraj    Male  33.0  Visakhapatnam
# 8            8  Aishwarya  Female  24.0      Bangalore
# 26          26     Aditya    Male  31.0       Srinagar
# 30          30     Prisha  Female  28.0       Varanasi
# 32          32     Chhavi  Female  25.0         Jaipur
# ...        ...        ...     ...   ...            ...
# 140685  140685   Aaradhya  Female  27.0          Surat
# 140686  140686      Rohan    Male  27.0       Ludhiana
# 140689  140689      Ayaan    Male  31.0      Faridabad
# 140690  140690      Rashi  Female  18.0       Ludhiana
# 140699  140699        Sai    Male  27.0          Patna
#
#        Working Professional or Student Profession  Academic Pressure  \
# 2                              Student        NaN                5.0
# 8                              Student        NaN                2.0
# 26                             Student        NaN                3.0
# ...

# %%
student_data_irrelevant_columns = ['Working Professional or Student','Work Pressure','CGPA','Job Satisfaction','Profession']
student_data = student_data.drop(columns=student_data_irrelevant_columns,axis=1)

# %% [markdown]
# Look into this outlier data:
#
# student_data[student_data['CGPA'].isna()].index
#
# Index([21880, 52737, 58062, 70453, 75007, 105773, 110097, 129756, 134830], dtype='int64')

# %% [markdown]
# Profession is also filled out for a number of students

# %%
student_data.to_csv('../data_split_0/student_train_data.csv',index=False)
